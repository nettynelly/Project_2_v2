# %%
##dependencies
import pandas as pd
import numpy as np
from flask import Flask, jsonify, render_template
import json
import sqlalchemy as db

# %%
#create db connection to each table and bring it in as a pandas df
engine = db.create_engine('sqlite:///static/health_plans.sqlite')
connection = engine.connect()
metadata = db.MetaData()
h15 = db.Table('h15',metadata, autoload=True,autoload_with=engine)
query = db.select([h15])
ResultProxy = connection.execute(query)
ResultSet = ResultProxy.fetchall()
h15 = pd.DataFrame(ResultSet)

engine = db.create_engine('sqlite:///static/health_plans.sqlite')
connection = engine.connect()
metadata = db.MetaData()
h16 = db.Table('h16',metadata, autoload=True,autoload_with=engine)
query = db.select([h16])
ResultProxy = connection.execute(query)
ResultSet = ResultProxy.fetchall()
h16 = pd.DataFrame(ResultSet)

engine = db.create_engine('sqlite:///static/health_plans.sqlite')
connection = engine.connect()
metadata = db.MetaData()
h17 = db.Table('h17',metadata, autoload=True,autoload_with=engine)
query = db.select([h17])
ResultProxy = connection.execute(query)
ResultSet = ResultProxy.fetchall()
h17 = pd.DataFrame(ResultSet)

engine = db.create_engine('sqlite:///static/health_plans.sqlite')
connection = engine.connect()
metadata = db.MetaData()
h18 = db.Table('h18',metadata, autoload=True,autoload_with=engine)
query = db.select([h18])
ResultProxy = connection.execute(query)
ResultSet = ResultProxy.fetchall()
h18 = pd.DataFrame(ResultSet)

# %%
#name columns
h15.columns = ['State','County','Metal','Issuer','Type','FIPS']
h16.columns = ['State','County','Metal','Issuer','Type','FIPS']
h17.columns = ['State','County','Metal','Issuer','Type','FIPS']
h18.columns = ['State','County','Metal','Issuer','Type','FIPS']

# %%
#create groupbys to operate on
state15_groupby = h15.groupby('State')
fips15_groupby = h15.groupby('FIPS')
state15_metal_groupby = h15.groupby(['Metal','State'])
fips15_metal_groupby = h15.groupby(['Metal','FIPS'])
state15_issuer_groupby = h15.groupby(['Issuer','State'])
fips15_issuer_groupby = h15.groupby(['Issuer','FIPS'])
state15_type_groupby = h15.groupby(['Type','State'])
fips15_type_groupby = h15.groupby(['Type','FIPS'])

state16_groupby = h16.groupby('State')
fips16_groupby = h16.groupby('FIPS')
state16_metal_groupby = h16.groupby(['Metal','State'])
fips16_metal_groupby = h16.groupby(['Metal','FIPS'])
state16_issuer_groupby = h16.groupby(['Issuer','State'])
fips16_issuer_groupby = h16.groupby(['Issuer','FIPS'])
state16_type_groupby = h16.groupby(['Type','State'])
fips16_type_groupby = h16.groupby(['Type','FIPS'])

state17_groupby = h17.groupby('State')
fips17_groupby = h17.groupby('FIPS')
state17_metal_groupby = h17.groupby(['Metal','State'])
fips17_metal_groupby = h17.groupby(['Metal','FIPS'])
state17_issuer_groupby = h17.groupby(['Issuer','State'])
fips17_issuer_groupby = h17.groupby(['Issuer','FIPS'])
state17_type_groupby = h17.groupby(['Type','State'])
fips17_type_groupby = h17.groupby(['Type','FIPS'])

state18_groupby = h18.groupby('State')
fips18_groupby = h18.groupby('FIPS')
state18_metal_groupby = h18.groupby(['Metal','State'])
fips18_metal_groupby = h18.groupby(['Metal','FIPS'])
state18_issuer_groupby = h18.groupby(['Issuer','State'])
fips18_issuer_groupby = h18.groupby(['Issuer','FIPS'])
state18_type_groupby = h18.groupby(['Type','State'])
fips18_type_groupby = h18.groupby(['Type','FIPS'])

# %%
#get counts for each groupby
state15_count = state15_groupby[['FIPS']].count()
#right now this is cast to a string because jsonify didn't like numpy results??
state15_count['FIPS'] = state15_count['FIPS'].astype(str)
state15_count = state15_count.reset_index(drop=False)
state15_count.columns = ['State','Count']

fips15_count = fips15_groupby[['Type']].count()
fips15_count['Type'] = fips15_count['Type'].astype(str)
fips15_count = fips15_count.reset_index(drop=False)
fips15_count.columns = ['FIPS','Count']
fips15_count['FIPS'] = fips15_count['FIPS'].astype(str)

state16_count = state16_groupby[['FIPS']].count()
state16_count['FIPS'] = state16_count['FIPS'].astype(str)
state16_count = state16_count.reset_index(drop=False)
state16_count.columns = ['State','Count']

fips16_count = fips16_groupby[['Type']].count()
fips16_count['Type'] = fips16_count['Type'].astype(str)
fips16_count = fips16_count.reset_index(drop=False)
fips16_count.columns = ['FIPS','Count']
fips16_count['FIPS'] = fips16_count['FIPS'].astype(str)

state17_count = state17_groupby[['FIPS']].count()
state17_count['FIPS'] = state17_count['FIPS'].astype(str)
state17_count = state17_count.reset_index(drop=False)
state17_count.columns = ['State','Count']

fips17_count = fips17_groupby[['Type']].count()
fips17_count['Type'] = fips17_count['Type'].astype(str)
fips17_count = fips17_count.reset_index(drop=False)
fips17_count.columns = ['FIPS','Count']
fips17_count['FIPS'] = fips17_count['FIPS'].astype(str)

state18_count = state18_groupby[['FIPS']].count()
state18_count['FIPS'] = state18_count['FIPS'].astype(str)
state18_count = state18_count.reset_index(drop=False)
state18_count.columns = ['State','Count']

fips18_count = fips18_groupby[['Type']].count()
fips18_count['Type'] = fips18_count['Type'].astype(str)
fips18_count = fips18_count.reset_index(drop=False)
fips18_count.columns = ['FIPS','Count']
fips18_count['FIPS'] = fips18_count['FIPS'].astype(str)

# %%
#get count for each metal type by state and FIPS
state15_metal_count = state15_metal_groupby[['FIPS']].count()
state15_metal_count['FIPS'] = state15_metal_count['FIPS'].astype(str)
state15_metal_count = state15_metal_count.reset_index(drop=False)
state15_metal_count.columns = ['Metal','State','Count']

fips15_metal_count = fips15_metal_groupby[['State']].count()
fips15_metal_count['State'] = fips15_metal_count['State'].astype(str)
fips15_metal_count = fips15_metal_count.reset_index(drop=False)
fips15_metal_count.columns = 'Metal','FIPS','Count'
fips15_metal_count['FIPS'] = fips15_metal_count['FIPS'].astype(str)

state16_metal_count = state16_metal_groupby[['FIPS']].count()
state16_metal_count['FIPS'] = state16_metal_count['FIPS'].astype(str)
state16_metal_count = state16_metal_count.reset_index(drop=False)
state16_metal_count.columns = ['Metal','State','Count']

fips16_metal_count = fips16_metal_groupby[['State']].count()
fips16_metal_count['State'] = fips16_metal_count['State'].astype(str)
fips16_metal_count = fips16_metal_count.reset_index(drop=False)
fips16_metal_count.columns = 'Metal','FIPS','Count'
fips16_metal_count['FIPS'] = fips16_metal_count['FIPS'].astype(str)

state17_metal_count = state17_metal_groupby[['FIPS']].count()
state17_metal_count['FIPS'] = state17_metal_count['FIPS'].astype(str)
state17_metal_count = state17_metal_count.reset_index(drop=False)
state17_metal_count.columns = ['Metal','State','Count']

fips17_metal_count = fips17_metal_groupby[['State']].count()
fips17_metal_count['State'] = fips17_metal_count['State'].astype(str)
fips17_metal_count = fips17_metal_count.reset_index(drop=False)
fips17_metal_count.columns = 'Metal','FIPS','Count'
fips17_metal_count['FIPS'] = fips17_metal_count['FIPS'].astype(str)

state18_metal_count = state18_metal_groupby[['FIPS']].count()
state18_metal_count['FIPS'] = state18_metal_count['FIPS'].astype(str)
state18_metal_count = state18_metal_count.reset_index(drop=False)
state18_metal_count.columns = ['Metal','State','Count']

fips18_metal_count = fips18_metal_groupby[['State']].count()
fips18_metal_count['State'] = fips18_metal_count['State'].astype(str)
fips18_metal_count = fips18_metal_count.reset_index(drop=False)
fips18_metal_count.columns = 'Metal','FIPS','Count'
fips18_metal_count['FIPS'] = fips18_metal_count['FIPS'].astype(str)

# %%
#get count for each issuer by state and FIPS
state15_issuer_count = state15_issuer_groupby[['FIPS']].count()
state15_issuer_count[['FIPS']] = state15_issuer_count[['FIPS']].astype(str)
state15_issuer_count = state15_issuer_count.reset_index(drop=False)
state15_issuer_count.columns = ['Issuer','State','Count']

fips15_issuer_count = fips15_issuer_groupby[['State']].count()
fips15_issuer_count[['State']] = fips15_issuer_count[['State']].astype(str)
fips15_issuer_count = fips15_issuer_count.reset_index(drop=False)
fips15_issuer_count.columns = ['Issuer','FIPS','Count']
fips15_issuer_count['FIPS'] = fips15_issuer_count['FIPS'].astype(str)

state16_issuer_count = state16_issuer_groupby[['FIPS']].count()
state16_issuer_count[['FIPS']] = state16_issuer_count[['FIPS']].astype(str)
state16_issuer_count = state16_issuer_count.reset_index(drop=False)
state16_issuer_count.columns = ['Issuer','State','Count']

fips16_issuer_count = fips16_issuer_groupby[['State']].count()
fips16_issuer_count[['State']] = fips16_issuer_count[['State']].astype(str)
fips16_issuer_count = fips16_issuer_count.reset_index(drop=False)
fips16_issuer_count.columns = ['Issuer','FIPS','Count']
fips16_issuer_count['FIPS'] = fips16_issuer_count['FIPS'].astype(str)

state17_issuer_count = state17_issuer_groupby[['FIPS']].count()
state17_issuer_count[['FIPS']] = state17_issuer_count[['FIPS']].astype(str)
state17_issuer_count = state17_issuer_count.reset_index(drop=False)
state17_issuer_count.columns = ['Issuer','State','Count']

fips17_issuer_count = fips17_issuer_groupby[['State']].count()
fips17_issuer_count[['State']] = fips17_issuer_count[['State']].astype(str)
fips17_issuer_count = fips17_issuer_count.reset_index(drop=False)
fips17_issuer_count.columns = ['Issuer','FIPS','Count']
fips17_issuer_count['FIPS'] = fips17_issuer_count['FIPS'].astype(str)

state18_issuer_count = state18_issuer_groupby[['FIPS']].count()
state18_issuer_count[['FIPS']] = state18_issuer_count[['FIPS']].astype(str)
state18_issuer_count = state18_issuer_count.reset_index(drop=False)
state18_issuer_count.columns = ['Issuer','State','Count']

fips18_issuer_count = fips18_issuer_groupby[['State']].count()
fips18_issuer_count[['State']] = fips18_issuer_count[['State']].astype(str)
fips18_issuer_count = fips18_issuer_count.reset_index(drop=False)
fips18_issuer_count.columns = ['Issuer','FIPS','Count']
fips18_issuer_count['FIPS'] = fips18_issuer_count['FIPS'].astype(str)

# %%
#get count of plan type for each state and FIPS
state15_type_count = state15_type_groupby[['FIPS']].count()
state15_type_count['FIPS'] = state15_type_count['FIPS'].astype(str)
state15_type_count = state15_type_count.reset_index(drop=False)
state15_type_count.columns = ['Type','State','Count']

fips15_type_count = fips15_type_groupby[['State']].count()
fips15_type_count['State'] = fips15_type_count['State'].astype(str)
fips15_type_count.columns = (['Count'])
fips15_type_count = fips15_type_count.reset_index(drop=False)
fips15_type_count.columns = ['Type','FIPS','Count']
fips15_type_count['FIPS'] = fips15_type_count['FIPS'].astype(str)

state16_type_count = state16_type_groupby[['FIPS']].count()
state16_type_count['FIPS'] = state16_type_count['FIPS'].astype(str)
state16_type_count = state16_type_count.reset_index(drop=False)
state16_type_count.columns = ['Type','State','Count']

fips16_type_count = fips16_type_groupby[['State']].count()
fips16_type_count['State'] = fips16_type_count['State'].astype(str)
fips16_type_count.columns = (['Count'])
fips16_type_count = fips16_type_count.reset_index(drop=False)
fips16_type_count.columns = ['Type','FIPS','Count']
fips16_type_count['FIPS'] = fips16_type_count['FIPS'].astype(str)

state17_type_count = state17_type_groupby[['FIPS']].count()
state17_type_count['FIPS'] = state17_type_count['FIPS'].astype(str)
state17_type_count = state17_type_count.reset_index(drop=False)
state17_type_count.columns = ['Type','State','Count']

fips17_type_count = fips17_type_groupby[['State']].count()
fips17_type_count['State'] = fips17_type_count['State'].astype(str)
fips17_type_count.columns = (['Count'])
fips17_type_count = fips17_type_count.reset_index(drop=False)
fips17_type_count.columns = ['Type','FIPS','Count']
fips17_type_count['FIPS'] = fips17_type_count['FIPS'].astype(str)
fips17_type_count['FIPS'] = fips17_type_count['FIPS'].str[:5]

state18_type_count = state18_type_groupby[['FIPS']].count()
state18_type_count['FIPS'] = state18_type_count['FIPS'].astype(str)
state18_type_count = state18_type_count.reset_index(drop=False)
state18_type_count.columns = ['Type','State','Count']

fips18_type_count = fips18_type_groupby[['State']].count()
fips18_type_count['State'] = fips18_type_count['State'].astype(str)
fips18_type_count.columns = (['Count'])
fips18_type_count = fips18_type_count.reset_index(drop=False)
fips18_type_count.columns = ['Type','FIPS','Count']
fips18_type_count['FIPS'] = fips18_type_count['FIPS'].astype(str)
fips18_type_count['FIPS'] = fips18_type_count['FIPS'].str[:5]

# %%
fips_type_count = fips18_type_count
fips_type_count['FIPS'] = fips_type_count['FIPS'].str[:5]
fips18_type_count.head()
# Out:
#                                                 Type   FIPS Count
# 0  \tGroup Health Cooperative of South Central Wi...  55021   748
# 1  \tGroup Health Cooperative of South Central Wi...  55025  4836
# 2  \tGroup Health Cooperative of South Central Wi...  55111  2068
# 3                         AultCare Insurance Company  39019  3600
# 4                         AultCare Insurance Company  39075  3600

# %%
#turn dfs into dicts for jsonification
state15_count_obs = []
pointer = state15_count
counter = 0
for plan in pointer.iterrows():
    state15_count_obs.append({'State':pointer.iloc[counter,0],'Count':pointer.iloc[counter,-1]})
    counter = counter +1

fips15_count_obs = []
pointer = fips15_count
counter = 0
for plan in pointer.iterrows():
    fips15_count_obs.append({'FIPS':pointer.iloc[counter,0],'Count':pointer.iloc[counter,-1]})
    counter = counter +1

state15_metal_obs = []
pointer = state15_metal_count
counter = 0
for plan in pointer.iterrows():
    state15_metal_obs.append({'State':pointer.iloc[counter,1],'Metal':pointer.iloc[counter,0],'Count':pointer.iloc[counter,-1]})
    counter = counter +1
    
fips15_metal_obs = []
pointer = fips15_metal_count
counter = 0
for plan in pointer.iterrows():
    fips15_metal_obs.append({'FIPS':pointer.iloc[counter,1],'Metal':pointer.iloc[counter,0],'Count':pointer.iloc[counter,-1]})
    counter = counter +1

state15_issuer_obs = []
pointer = state15_issuer_count
counter = 0
for plan in pointer.iterrows():
    state15_issuer_obs.append({'State':pointer.iloc[counter,1],'Count':pointer.iloc[counter,-1], 'Issuer':pointer.iloc[counter,0]})
    counter = counter +1
    
fips15_issuer_obs = []
pointer = fips15_issuer_count
counter = 0
for plan in pointer.iterrows():
    fips15_issuer_obs.append({'FIPS':pointer.iloc[counter,1],'Count':pointer.iloc[counter,-1], 'Issuer':pointer.iloc[counter,0]})
    counter = counter +1
    
state15_type_obs = []
pointer = state15_type_count
counter = 0
for plan in pointer.iterrows():
    state15_type_obs.append({'State':pointer.iloc[counter,1],'Count':pointer.iloc[counter,-1], 'Type':pointer.iloc[counter,0]})
    counter = counter +1
    
fips15_type_obs = []
pointer = fips15_type_count
counter = 0
for plan in pointer.iterrows():
    fips15_type_obs.append({'FIPS':pointer.iloc[counter,1],'Count':pointer.iloc[counter,-1], 'Type':pointer.iloc[counter,0]})
    counter = counter +1
    
###end of year

#turn dfs into dicts for jsonification
state16_count_obs = []
pointer = state16_count
counter = 0
for plan in pointer.iterrows():
    state16_count_obs.append({'State':pointer.iloc[counter,0],'Count':pointer.iloc[counter,-1]})
    counter = counter +1

fips16_count_obs = []
pointer = fips16_count
counter = 0
for plan in pointer.iterrows():
    fips16_count_obs.append({'FIPS':pointer.iloc[counter,0],'Count':pointer.iloc[counter,-1]})
    counter = counter +1

state16_metal_obs = []
pointer = state16_metal_count
counter = 0
for plan in pointer.iterrows():
    state16_metal_obs.append({'State':pointer.iloc[counter,1],'Metal':pointer.iloc[counter,0],'Count':pointer.iloc[counter,-1]})
    counter = counter +1
    
fips16_metal_obs = []
pointer = fips16_metal_count
counter = 0
for plan in pointer.iterrows():
    fips16_metal_obs.append({'FIPS':pointer.iloc[counter,1],'Metal':pointer.iloc[counter,0],'Count':pointer.iloc[counter,-1]})
    counter = counter +1

state16_issuer_obs = []
pointer = state16_issuer_count
counter = 0
for plan in pointer.iterrows():
    state16_issuer_obs.append({'State':pointer.iloc[counter,1],'Count':pointer.iloc[counter,-1], 'Issuer':pointer.iloc[counter,0]})
    counter = counter +1
    
fips16_issuer_obs = []
pointer = fips16_issuer_count
counter = 0
for plan in pointer.iterrows():
    fips16_issuer_obs.append({'FIPS':pointer.iloc[counter,1],'Count':pointer.iloc[counter,-1], 'Issuer':pointer.iloc[counter,0]})
    counter = counter +1
    
state16_type_obs = []
pointer = state16_type_count
counter = 0
for plan in pointer.iterrows():
    state16_type_obs.append({'State':pointer.iloc[counter,1],'Count':pointer.iloc[counter,-1], 'Type':pointer.iloc[counter,0]})
    counter = counter +1
    
fips16_type_obs = []
pointer = fips16_type_count
counter = 0
for plan in pointer.iterrows():
    fips16_type_obs.append({'FIPS':pointer.iloc[counter,1],'Count':pointer.iloc[counter,-1], 'Type':pointer.iloc[counter,0]})
    counter = counter +1
    
###end of year

#turn dfs into dicts for jsonification
state17_count_obs = []
pointer = state17_count
counter = 0
for plan in pointer.iterrows():
    state17_count_obs.append({'State':pointer.iloc[counter,0],'Count':pointer.iloc[counter,-1]})
    counter = counter +1

fips17_count_obs = []
pointer = fips17_count
counter = 0
for plan in pointer.iterrows():
    fips17_count_obs.append({'FIPS':pointer.iloc[counter,0],'Count':pointer.iloc[counter,-1]})
    counter = counter +1

state17_metal_obs = []
pointer = state17_metal_count
counter = 0
for plan in pointer.iterrows():
    state17_metal_obs.append({'State':pointer.iloc[counter,1],'Metal':pointer.iloc[counter,0],'Count':pointer.iloc[counter,-1]})
    counter = counter +1
    
fips17_metal_obs = []
pointer = fips17_metal_count
counter = 0
for plan in pointer.iterrows():
    fips17_metal_obs.append({'FIPS':pointer.iloc[counter,1],'Metal':pointer.iloc[counter,0],'Count':pointer.iloc[counter,-1]})
    counter = counter +1

state17_issuer_obs = []
pointer = state17_issuer_count
counter = 0
for plan in pointer.iterrows():
    state17_issuer_obs.append({'State':pointer.iloc[counter,1],'Count':pointer.iloc[counter,-1], 'Issuer':pointer.iloc[counter,0]})
    counter = counter +1
    
fips17_issuer_obs = []
pointer = fips17_issuer_count
counter = 0
for plan in pointer.iterrows():
    fips17_issuer_obs.append({'FIPS':pointer.iloc[counter,1],'Count':pointer.iloc[counter,-1], 'Issuer':pointer.iloc[counter,0]})
    counter = counter +1
    
state17_type_obs = []
pointer = state17_type_count
counter = 0
for plan in pointer.iterrows():
    state17_type_obs.append({'State':pointer.iloc[counter,1],'Count':pointer.iloc[counter,-1], 'Type':pointer.iloc[counter,0]})
    counter = counter +1
    
fips17_type_obs = []
pointer = fips17_type_count
counter = 0
for plan in pointer.iterrows():
    fips17_type_obs.append({'FIPS':pointer.iloc[counter,1],'Count':pointer.iloc[counter,-1], 'Type':pointer.iloc[counter,0]})
    counter = counter +1
    
###end of year

#turn dfs into dicts for jsonification
state18_count_obs = []
pointer = state18_count
counter = 0
for plan in pointer.iterrows():
    state18_count_obs.append({'State':pointer.iloc[counter,0],'Count':pointer.iloc[counter,-1]})
    counter = counter +1

fips18_count_obs = []
pointer = fips18_count
counter = 0
for plan in pointer.iterrows():
    fips18_count_obs.append({'FIPS':pointer.iloc[counter,0],'Count':pointer.iloc[counter,-1]})
    counter = counter +1

state18_metal_obs = []
pointer = state18_metal_count
counter = 0
for plan in pointer.iterrows():
    state18_metal_obs.append({'State':pointer.iloc[counter,1],'Metal':pointer.iloc[counter,0],'Count':pointer.iloc[counter,-1]})
    counter = counter +1
    
fips18_metal_obs = []
pointer = fips18_metal_count
counter = 0
for plan in pointer.iterrows():
    fips18_metal_obs.append({'FIPS':pointer.iloc[counter,1],'Metal':pointer.iloc[counter,0],'Count':pointer.iloc[counter,-1]})
    counter = counter +1

state18_issuer_obs = []
pointer = state18_issuer_count
counter = 0
for plan in pointer.iterrows():
    state18_issuer_obs.append({'State':pointer.iloc[counter,1],'Count':pointer.iloc[counter,-1], 'Issuer':pointer.iloc[counter,0]})
    counter = counter +1
    
fips18_issuer_obs = []
pointer = fips18_issuer_count
counter = 0
for plan in pointer.iterrows():
    fips18_issuer_obs.append({'FIPS':pointer.iloc[counter,1],'Count':pointer.iloc[counter,-1], 'Issuer':pointer.iloc[counter,0]})
    counter = counter +1
    
state18_type_obs = []
pointer = state18_type_count
counter = 0
for plan in pointer.iterrows():
    state18_type_obs.append({'State':pointer.iloc[counter,1],'Count':pointer.iloc[counter,-1], 'Type':pointer.iloc[counter,0]})
    counter = counter +1
    
fips18_type_obs = []
pointer = fips18_type_count
counter = 0
for plan in pointer.iterrows():
    fips18_type_obs.append({'FIPS':pointer.iloc[counter,1],'Count':pointer.iloc[counter,-1], 'Type':pointer.iloc[counter,0]})
    counter = counter +1
    
###end of year

# %%
fips18_type_obs
# Out:
# [{'FIPS': '55021',
#   'Count': '748',
#   'Type': '\tGroup Health Cooperative of South Central Wisconsin'},
#  {'FIPS': '55025',
#   'Count': '4836',
#   'Type': '\tGroup Health Cooperative of South Central Wisconsin'},
#  {'FIPS': '55111',
#   'Count': '2068',
#   'Type': '\tGroup Health Cooperative of South Central Wisconsin'},
#  {'FIPS': '39019', 'Count': '3600', 'Type': 'AultCare Insurance Company'},
#  {'FIPS': '39075', 'Count': '3600', 'Type': 'AultCare Insurance Company'},
#  {'FIPS': '39151', 'Count': '3960', 'Type': 'AultCare Insurance Company'},
#  {'FIPS': '39153', 'Count': '3960', 'Type': 'AultCare Insurance Company'},
#  {'FIPS': '39157', 'Count': '3600', 'Type': 'AultCare Insurance Company'},
#  {'FIPS': '39169', 'Count': '3600', 'Type': 'AultCare Insurance Company'},
#  {'FIPS': '1001.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1003.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1005.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1007.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1009.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1011.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1013.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1015.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1017.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1019.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1021.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1023.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1025.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1027.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1029.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1031.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1033.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1035.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1037.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1039.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1041.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1043.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1045.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1047.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1049.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1051.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1053.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1055.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1057.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1059.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1061.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1063.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1065.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1067.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1069.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1071.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1073.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1075.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1077.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1079.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1081.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1083.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1085.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1087.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1089.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1091.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1093.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1095.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1097.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1099.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1101.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1103.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1105.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1107.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1109.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1111.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1113.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1115.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1117.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1119.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1121.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1123.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1125.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1127.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1129.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1131.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '1133.',
#   'Count': '72',
#   'Type': 'Blue Cross and Blue Shield of Alabama'},
#  {'FIPS': '51013', 'Count': '156', 'Type': 'CareFirst BlueChoice, Inc.'},
#  {'FIPS': '51059', 'Count': '204', 'Type': 'CareFirst BlueChoice, Inc.'},
#  {'FIPS': '51107', 'Count': '204', 'Type': 'CareFirst BlueChoice, Inc.'},
#  {'FIPS': '51153', 'Count': '204', 'Type': 'CareFirst BlueChoice, Inc.'},
#  {'FIPS': '51510', 'Count': '156', 'Type': 'CareFirst BlueChoice, Inc.'},
#  {'FIPS': '51600', 'Count': '156', 'Type': 'CareFirst BlueChoice, Inc.'},
#  {'FIPS': '51610', 'Count': '156', 'Type': 'CareFirst BlueChoice, Inc.'},
#  {'FIPS': '55009',
#   'Count': '2728',
#   'Type': 'Common Ground Healthcare Cooperative'},
#  {'FIPS': '55015',
#   'Count': '2728',
#   'Type': 'Common Ground Healthcare Cooperative'},
#  {'FIPS': '55029',
#   'Count': '2728',
#   'Type': 'Common Ground Healthcare Cooperative'},
#  {'FIPS': '55039',
#   'Count': '2728',
#   'Type': 'Common Ground Healthcare Cooperative'},
#  {'FIPS': '55059',
#   'Count': '2728',
#   'Type': 'Common Ground Healthcare Cooperative'},
#  {'FIPS': '55061',
#   'Count': '2728',
#   'Type': 'Common Ground Healthcare Cooperative'},
#  {'FIPS': '55071',
#   'Count': '2728',
#   'Type': 'Common Ground Healthcare Cooperative'},
#  {'FIPS': '55075',
#   'Count': '2728',
#   'Type': 'Common Ground Healthcare Cooperative'},
#  {'FIPS': '55079',
#   'Count': '2728',
#   'Type': 'Common Ground Healthcare Cooperative'},
#  {'FIPS': '55083',
#   'Count': '2728',
#   'Type': 'Common Ground Healthcare Cooperative'},
#  {'FIPS': '55087',
#   'Count': '2728',
#   'Type': 'Common Ground Healthcare Cooperative'},
#  {'FIPS': '55089',
#   'Count': '2728',
#   'Type': 'Common Ground Healthcare Cooperative'},
#  {'FIPS': '55101',
#   'Count': '2728',
#   'Type': 'Common Ground Healthcare Cooperative'},
#  {'FIPS': '55115',
#   'Count': '5368',
#   'Type': 'Common Ground Healthcare Cooperative'},
#  {'FIPS': '55117',
#   'Count': '2728',
#   'Type': 'Common Ground Healthcare Cooperative'},
#  {'FIPS': '55127',
#   'Count': '3652',
#   'Type': 'Common Ground Healthcare Cooperative'},
#  {'FIPS': '55131',
#   'Count': '2728',
#   'Type': 'Common Ground Healthcare Cooperative'},
#  {'FIPS': '55133',
#   'Count': '2728',
#   'Type': 'Common Ground Healthcare Cooperative'},
#  {'FIPS': '55139',
#   'Count': '2728',
#   'Type': 'Common Ground Healthcare Cooperative'},
#  {'FIPS': '40027', 'Count': '2912', 'Type': 'CommunityCare HMO Inc.'},
#  {'FIPS': '40035', 'Count': '1536', 'Type': 'CommunityCare HMO Inc.'},
#  {'FIPS': '40037', 'Count': '2912', 'Type': 'CommunityCare HMO Inc.'},
#  {'FIPS': '40101', 'Count': '1536', 'Type': 'CommunityCare HMO Inc.'},
#  {'FIPS': '40105', 'Count': '2688', 'Type': 'CommunityCare HMO Inc.'},
#  {'FIPS': '40109', 'Count': '2912', 'Type': 'CommunityCare HMO Inc.'},
#  {'FIPS': '40111', 'Count': '2912', 'Type': 'CommunityCare HMO Inc.'},
#  {'FIPS': '40113', 'Count': '2912', 'Type': 'CommunityCare HMO Inc.'},
#  {'FIPS': '40131', 'Count': '2912', 'Type': 'CommunityCare HMO Inc.'},
#  {'FIPS': '40143', 'Count': '2912', 'Type': 'CommunityCare HMO Inc.'},
#  {'FIPS': '40145', 'Count': '2912', 'Type': 'CommunityCare HMO Inc.'},
#  {'FIPS': '40147', 'Count': '2688', 'Type': 'CommunityCare HMO Inc.'},
#  {'FIPS': '40027',
#   'Count': '2002',
#   'Type': 'CommunityCare Life & Health Insurance Co'},
#  {'FIPS': '40035',
#   'Count': '1056',
#   'Type': 'CommunityCare Life & Health Insurance Co'},
#  {'FIPS': '40037',
#   'Count': '2002',
#   'Type': 'CommunityCare Life & Health Insurance Co'},
#  {'FIPS': '40101',
#   'Count': '1056',
#   'Type': 'CommunityCare Life & Health Insurance Co'},
#  {'FIPS': '40105',
#   'Count': '1848',
#   'Type': 'CommunityCare Life & Health Insurance Co'},
#  {'FIPS': '40109',
#   'Count': '2002',
#   'Type': 'CommunityCare Life & Health Insurance Co'},
#  {'FIPS': '40111',
#   'Count': '2002',
#   'Type': 'CommunityCare Life & Health Insurance Co'},
#  {'FIPS': '40113',
#   'Count': '2002',
#   'Type': 'CommunityCare Life & Health Insurance Co'},
#  {'FIPS': '40131',
#   'Count': '2002',
#   'Type': 'CommunityCare Life & Health Insurance Co'},
#  {'FIPS': '40143',
#   'Count': '2002',
#   'Type': 'CommunityCare Life & Health Insurance Co'},
#  {'FIPS': '40145',
#   'Count': '2002',
#   'Type': 'CommunityCare Life & Health Insurance Co'},
#  {'FIPS': '40147',
#   'Count': '1848',
#   'Type': 'CommunityCare Life & Health Insurance Co'},
#  {'FIPS': '51013',
#   'Count': '156',
#   'Type': 'Group Hospitalization and Medical Services Inc.'},
#  {'FIPS': '51059',
#   'Count': '204',
#   'Type': 'Group Hospitalization and Medical Services Inc.'},
#  {'FIPS': '51107',
#   'Count': '204',
#   'Type': 'Group Hospitalization and Medical Services Inc.'},
#  {'FIPS': '51153',
#   'Count': '204',
#   'Type': 'Group Hospitalization and Medical Services Inc.'},
#  {'FIPS': '51510',
#   'Count': '156',
#   'Type': 'Group Hospitalization and Medical Services Inc.'},
#  {'FIPS': '51600',
#   'Count': '156',
#   'Type': 'Group Hospitalization and Medical Services Inc.'},
#  {'FIPS': '51610',
#   'Count': '156',
#   'Type': 'Group Hospitalization and Medical Services Inc.'},
#  {'FIPS': '17001',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17003',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17005',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17007',
#   'Count': '1240',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17009',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17011',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17013',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17015',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17017',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17019',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17021',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17023',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17025',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17027',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17029',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17033',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17035',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17037',
#   'Count': '1240',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17039',
#   'Count': '1240',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17041',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17045',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17047',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17049',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17051',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17053',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17055',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17057',
#   'Count': '2304',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17059',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17061',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17063',
#   'Count': '1240',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17065',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17067',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17069',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17071',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17073',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17075',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17077',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17079',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17081',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17083',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17085',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17087',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17091',
#   'Count': '1240',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17093',
#   'Count': '1240',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17095',
#   'Count': '2304',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17099',
#   'Count': '2304',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17101',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17103',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17105',
#   'Count': '1240',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17107',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17109',
#   'Count': '2304',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17113',
#   'Count': '1240',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17115',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17117',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17119',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17121',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17123',
#   'Count': '2520',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17125',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17127',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17129',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17131',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17133',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17135',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17137',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17139',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17141',
#   'Count': '1240',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17143',
#   'Count': '2520',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17145',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17147',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17149',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17151',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17153',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17155',
#   'Count': '2304',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17157',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17159',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17161',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17163',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17165',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17167',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17169',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17171',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17173',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17175',
#   'Count': '2520',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17177',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17179',
#   'Count': '2520',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17181',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17183',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17185',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17187',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17189',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17191',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17193',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17195',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17197',
#   'Count': '1360',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17199',
#   'Count': '1120',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17201',
#   'Count': '1240',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '17203',
#   'Count': '2520',
#   'Type': 'Health Alliance Medical Plans, Inc.'},
#  {'FIPS': '12009',
#   'Count': '10296',
#   'Type': 'Health First Commercial Plans, Inc.'},
#  {'FIPS': '12035',
#   'Count': '8568',
#   'Type': 'Health First Commercial Plans, Inc.'},
#  {'FIPS': '12061',
#   'Count': '6396',
#   'Type': 'Health First Commercial Plans, Inc.'},
#  {'FIPS': '12127',
#   'Count': '8568',
#   'Type': 'Health First Commercial Plans, Inc.'},
#  {'FIPS': '34001',
#   'Count': '1040',
#   'Type': 'Horizon Healthcare Services, Inc.'},
#  {'FIPS': '34003',
#   'Count': '980',
#   'Type': 'Horizon Healthcare Services, Inc.'},
#  {'FIPS': '34005',
#   'Count': '1040',
#   'Type': 'Horizon Healthcare Services, Inc.'},
#  {'FIPS': '34007',
#   'Count': '1040',
#   'Type': 'Horizon Healthcare Services, Inc.'},
#  {'FIPS': '34009',
#   'Count': '1040',
#   'Type': 'Horizon Healthcare Services, Inc.'},
#  {'FIPS': '34011',
#   'Count': '980',
#   'Type': 'Horizon Healthcare Services, Inc.'},
#  {'FIPS': '34013',
#   'Count': '980',
#   'Type': 'Horizon Healthcare Services, Inc.'},
#  {'FIPS': '34015',
#   'Count': '1040',
#   'Type': 'Horizon Healthcare Services, Inc.'},
#  {'FIPS': '34017',
#   'Count': '980',
#   'Type': 'Horizon Healthcare Services, Inc.'},
#  {'FIPS': '34019',
#   'Count': '840',
#   'Type': 'Horizon Healthcare Services, Inc.'},
#  {'FIPS': '34021',
#   'Count': '1000',
#   'Type': 'Horizon Healthcare Services, Inc.'},
#  {'FIPS': '34023',
#   'Count': '1000',
#   'Type': 'Horizon Healthcare Services, Inc.'},
#  {'FIPS': '34025',
#   'Count': '1060',
#   'Type': 'Horizon Healthcare Services, Inc.'},
#  {'FIPS': '34027',
#   'Count': '980',
#   'Type': 'Horizon Healthcare Services, Inc.'},
#  {'FIPS': '34029',
#   'Count': '1060',
#   'Type': 'Horizon Healthcare Services, Inc.'},
#  {'FIPS': '34031',
#   'Count': '980',
#   'Type': 'Horizon Healthcare Services, Inc.'},
#  {'FIPS': '34033',
#   'Count': '920',
#   'Type': 'Horizon Healthcare Services, Inc.'},
#  {'FIPS': '34035',
#   'Count': '980',
#   'Type': 'Horizon Healthcare Services, Inc.'},
#  {'FIPS': '34037',
#   'Count': '980',
#   'Type': 'Horizon Healthcare Services, Inc.'},
#  {'FIPS': '34039',
#   'Count': '980',
#   'Type': 'Horizon Healthcare Services, Inc.'},
#  {'FIPS': '34041',
#   'Count': '980',
#   'Type': 'Horizon Healthcare Services, Inc.'},
#  {'FIPS': '13013',
#   'Count': '1290',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13015',
#   'Count': '1290',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13035',
#   'Count': '630',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13045',
#   'Count': '1290',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13057',
#   'Count': '1290',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13059',
#   'Count': '630',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13063',
#   'Count': '630',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13067',
#   'Count': '630',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13077',
#   'Count': '630',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13085',
#   'Count': '1290',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13089',
#   'Count': '630',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13097',
#   'Count': '630',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13113',
#   'Count': '630',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13117',
#   'Count': '1290',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13121',
#   'Count': '630',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13135',
#   'Count': '630',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13139',
#   'Count': '1290',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13143',
#   'Count': '1290',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13149',
#   'Count': '1290',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13151',
#   'Count': '630',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13171',
#   'Count': '630',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13195',
#   'Count': '630',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13199',
#   'Count': '450',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13217',
#   'Count': '630',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13219',
#   'Count': '630',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13221',
#   'Count': '630',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13223',
#   'Count': '630',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13227',
#   'Count': '1290',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13231',
#   'Count': '450',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13247',
#   'Count': '630',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13255',
#   'Count': '630',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '13297',
#   'Count': '630',
#   'Type': 'Kaiser Foundation Health Plan of Georgia'},
#  {'FIPS': '51013',
#   'Count': '728',
#   'Type': 'Kaiser Foundation Health Plan of the Mid-Atlantic States, Inc.'},
#  {'FIPS': '51033',
#   'Count': '644',
#   'Type': 'Kaiser Foundation Health Plan of the Mid-Atlantic States, Inc.'},
#  {'FIPS': '51047',
#   'Count': '644',
#   'Type': 'Kaiser Foundation Health Plan of the Mid-Atlantic States, Inc.'},
#  {'FIPS': '51059',
#   'Count': '952',
#   'Type': 'Kaiser Foundation Health Plan of the Mid-Atlantic States, Inc.'},
#  {'FIPS': '51061',
#   'Count': '644',
#   'Type': 'Kaiser Foundation Health Plan of the Mid-Atlantic States, Inc.'},
#  {'FIPS': '51085',
#   'Count': '644',
#   'Type': 'Kaiser Foundation Health Plan of the Mid-Atlantic States, Inc.'},
#  {'FIPS': '51099',
#   'Count': '644',
#   'Type': 'Kaiser Foundation Health Plan of the Mid-Atlantic States, Inc.'},
#  {'FIPS': '51107',
#   'Count': '952',
#   'Type': 'Kaiser Foundation Health Plan of the Mid-Atlantic States, Inc.'},
#  {'FIPS': '51109',
#   'Count': '644',
#   'Type': 'Kaiser Foundation Health Plan of the Mid-Atlantic States, Inc.'},
#  {'FIPS': '51137',
#   'Count': '644',
#   'Type': 'Kaiser Foundation Health Plan of the Mid-Atlantic States, Inc.'},
#  {'FIPS': '51153',
#   'Count': '952',
#   'Type': 'Kaiser Foundation Health Plan of the Mid-Atlantic States, Inc.'},
#  {'FIPS': '51177',
#   'Count': '728',
#   'Type': 'Kaiser Foundation Health Plan of the Mid-Atlantic States, Inc.'},
#  {'FIPS': '51179',
#   'Count': '728',
#   'Type': 'Kaiser Foundation Health Plan of the Mid-Atlantic States, Inc.'},
#  {'FIPS': '51193',
#   'Count': '644',
#   'Type': 'Kaiser Foundation Health Plan of the Mid-Atlantic States, Inc.'},
#  {'FIPS': '51510',
#   'Count': '728',
#   'Type': 'Kaiser Foundation Health Plan of the Mid-Atlantic States, Inc.'},
#  {'FIPS': '51600',
#   'Count': '728',
#   'Type': 'Kaiser Foundation Health Plan of the Mid-Atlantic States, Inc.'},
#  {'FIPS': '51610',
#   'Count': '728',
#   'Type': 'Kaiser Foundation Health Plan of the Mid-Atlantic States, Inc.'},
#  {'FIPS': '51630',
#   'Count': '728',
#   'Type': 'Kaiser Foundation Health Plan of the Mid-Atlantic States, Inc.'},
#  {'FIPS': '51683',
#   'Count': '728',
#   'Type': 'Kaiser Foundation Health Plan of the Mid-Atlantic States, Inc.'},
#  {'FIPS': '51685',
#   'Count': '728',
#   'Type': 'Kaiser Foundation Health Plan of the Mid-Atlantic States, Inc.'},
#  {'FIPS': '23001', 'Count': '200', 'Type': 'Maine Community Health Options'},
#  {'FIPS': '23003', 'Count': '168', 'Type': 'Maine Community Health Options'},
#  {'FIPS': '23005', 'Count': '200', 'Type': 'Maine Community Health Options'},
#  {'FIPS': '23007', 'Count': '200', 'Type': 'Maine Community Health Options'},
#  {'FIPS': '23009', 'Count': '168', 'Type': 'Maine Community Health Options'},
#  {'FIPS': '23011', 'Count': '200', 'Type': 'Maine Community Health Options'},
#  {'FIPS': '23013', 'Count': '200', 'Type': 'Maine Community Health Options'},
#  {'FIPS': '23015', 'Count': '200', 'Type': 'Maine Community Health Options'},
#  {'FIPS': '23017', 'Count': '200', 'Type': 'Maine Community Health Options'},
#  {'FIPS': '23019', 'Count': '168', 'Type': 'Maine Community Health Options'},
#  {'FIPS': '23021', 'Count': '168', 'Type': 'Maine Community Health Options'},
#  {'FIPS': '23023', 'Count': '200', 'Type': 'Maine Community Health Options'},
#  {'FIPS': '23025', 'Count': '168', 'Type': 'Maine Community Health Options'},
#  {'FIPS': '23027', 'Count': '200', 'Type': 'Maine Community Health Options'},
#  {'FIPS': '23029', 'Count': '168', 'Type': 'Maine Community Health Options'},
#  {'FIPS': '23031', 'Count': '200', 'Type': 'Maine Community Health Options'},
#  {'FIPS': '33001',
#   'Count': '360',
#   'Type': 'Matthew Thornton Hlth Plan(Anthem BCBS)'},
#  {'FIPS': '33003',
#   'Count': '300',
#   'Type': 'Matthew Thornton Hlth Plan(Anthem BCBS)'},
#  {'FIPS': '33005',
#   'Count': '324',
#   'Type': 'Matthew Thornton Hlth Plan(Anthem BCBS)'},
#  {'FIPS': '33007',
#   'Count': '360',
#   'Type': 'Matthew Thornton Hlth Plan(Anthem BCBS)'},
#  {'FIPS': '33009',
#   'Count': '360',
#   'Type': 'Matthew Thornton Hlth Plan(Anthem BCBS)'},
#  {'FIPS': '33011',
#   'Count': '360',
#   'Type': 'Matthew Thornton Hlth Plan(Anthem BCBS)'},
#  {'FIPS': '33013',
#   'Count': '360',
#   'Type': 'Matthew Thornton Hlth Plan(Anthem BCBS)'},
#  {'FIPS': '33015',
#   'Count': '360',
#   'Type': 'Matthew Thornton Hlth Plan(Anthem BCBS)'},
#  {'FIPS': '33017',
#   'Count': '360',
#   'Type': 'Matthew Thornton Hlth Plan(Anthem BCBS)'},
#  {'FIPS': '33019',
#   'Count': '360',
#   'Type': 'Matthew Thornton Hlth Plan(Anthem BCBS)'},
#  {'FIPS': '26001', 'Count': '140', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26005', 'Count': '126', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26007', 'Count': '168', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26009', 'Count': '168', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26011', 'Count': '168', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26015', 'Count': '126', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26017', 'Count': '168', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26019', 'Count': '126', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26023', 'Count': '126', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26027', 'Count': '126', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26029', 'Count': '168', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26031', 'Count': '168', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26035', 'Count': '126', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26037', 'Count': '168', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26039', 'Count': '126', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26045', 'Count': '168', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26047', 'Count': '168', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26049', 'Count': '308', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26051', 'Count': '126', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26055', 'Count': '126', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26057', 'Count': '126', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26059', 'Count': '168', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26063', 'Count': '168', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26065', 'Count': '168', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26067', 'Count': '168', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26069', 'Count': '168', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26073', 'Count': '168', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26077', 'Count': '126', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26079', 'Count': '126', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26081', 'Count': '126', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26085', 'Count': '126', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26087', 'Count': '168', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26089', 'Count': '126', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26091', 'Count': '126', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26093', 'Count': '126', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26099', 'Count': '308', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26101', 'Count': '126', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26105', 'Count': '126', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26107', 'Count': '126', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26111', 'Count': '126', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26113', 'Count': '98', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26115', 'Count': '168', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26117', 'Count': '168', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26119', 'Count': '168', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26123', 'Count': '126', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26125', 'Count': '308', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26127', 'Count': '126', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26129', 'Count': '168', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26133', 'Count': '126', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26135', 'Count': '140', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26137', 'Count': '168', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26139', 'Count': '126', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26141', 'Count': '168', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26143', 'Count': '168', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26145', 'Count': '168', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26147', 'Count': '168', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26149', 'Count': '126', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26151', 'Count': '168', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26155', 'Count': '168', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26157', 'Count': '168', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26159', 'Count': '126', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26161', 'Count': '168', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26163', 'Count': '308', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '26165', 'Count': '126', 'Type': 'McLaren Health Plan Community'},
#  {'FIPS': '2013.', 'Count': '1848', 'Type': 'Moda Health Plan, Inc.'},
#  {'FIPS': '2016.', 'Count': '1848', 'Type': 'Moda Health Plan, Inc.'},
#  {'FIPS': '2020.', 'Count': '1848', 'Type': 'Moda Health Plan, Inc.'},
#  {'FIPS': '2050.', 'Count': '1848', 'Type': 'Moda Health Plan, Inc.'},
#  {'FIPS': '2060.', 'Count': '1848', 'Type': 'Moda Health Plan, Inc.'},
#  {'FIPS': '2068.', 'Count': '1848', 'Type': 'Moda Health Plan, Inc.'},
#  {'FIPS': '2070.', 'Count': '1848', 'Type': 'Moda Health Plan, Inc.'},
#  {'FIPS': '2090.', 'Count': '1848', 'Type': 'Moda Health Plan, Inc.'},
#  {'FIPS': '2100.', 'Count': '1848', 'Type': 'Moda Health Plan, Inc.'},
#  {'FIPS': '2105.', 'Count': '1848', 'Type': 'Moda Health Plan, Inc.'},
#  {'FIPS': '2110.', 'Count': '1848', 'Type': 'Moda Health Plan, Inc.'},
#  {'FIPS': '2122.', 'Count': '1848', 'Type': 'Moda Health Plan, Inc.'},
#  {'FIPS': '2130.', 'Count': '1848', 'Type': 'Moda Health Plan, Inc.'},
#  {'FIPS': '2150.', 'Count': '1848', 'Type': 'Moda Health Plan, Inc.'},
#  {'FIPS': '2164.', 'Count': '1848', 'Type': 'Moda Health Plan, Inc.'},
#  {'FIPS': '2170.', 'Count': '1848', 'Type': 'Moda Health Plan, Inc.'},
#  {'FIPS': '2180.', 'Count': '1848', 'Type': 'Moda Health Plan, Inc.'},
#  {'FIPS': '2185.', 'Count': '1848', 'Type': 'Moda Health Plan, Inc.'},
#  {'FIPS': '2188.', 'Count': '1848', 'Type': 'Moda Health Plan, Inc.'},
#  {'FIPS': '2195.', 'Count': '1848', 'Type': 'Moda Health Plan, Inc.'},
#  {'FIPS': '2198.', 'Count': '1848', 'Type': 'Moda Health Plan, Inc.'},
#  {'FIPS': '2220.', 'Count': '1848', 'Type': 'Moda Health Plan, Inc.'},
#  {'FIPS': '2230.', 'Count': '1848', 'Type': 'Moda Health Plan, Inc.'},
#  {'FIPS': '2240.', 'Count': '1848', 'Type': 'Moda Health Plan, Inc.'},
#  {'FIPS': '2261.', 'Count': '1848', 'Type': 'Moda Health Plan, Inc.'},
#  {'FIPS': '2275.', 'Count': '1848', 'Type': 'Moda Health Plan, Inc.'},
#  {'FIPS': '2282.', 'Count': '1848', 'Type': 'Moda Health Plan, Inc.'},
#  {'FIPS': '2290.', 'Count': '1848', 'Type': 'Moda Health Plan, Inc.'},
#  {'FIPS': '30001', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30003', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30005', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30007', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30009', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30011', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30013', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30015', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30017', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30019', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30021', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30023', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30025', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30027', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30029', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30031', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30033', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30035', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30037', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30039', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30041', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30043', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30045', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30047', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30049', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30051', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30053', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30055', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30057', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30059', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30061', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30063', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30065', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30067', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30069', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30071', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30073', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30075', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30077', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30079', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30081', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30083', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30085', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30087', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30089', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30091', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30093', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30095', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30097', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30099', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30101', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30103', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30105', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30107', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30109', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30111', 'Count': '912', 'Type': 'Montana Health Cooperative'},
#  {'FIPS': '30001', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30003', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30005', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30007', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30009', 'Count': '2280', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30011', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30013', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30015', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30017', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30019', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30021', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30023', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30025', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30027', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30029', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30031', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30033', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30035', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30037', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30039', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30041', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30043', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30045', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30047', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30049', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30051', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30053', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30055', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30057', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30059', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30061', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30063', 'Count': '2280', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30065', 'Count': '2280', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30067', 'Count': '2280', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30069', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30071', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30073', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30075', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30077', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30079', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30081', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30083', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30085', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30087', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30089', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30091', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30093', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30095', 'Count': '2280', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30097', 'Count': '2280', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30099', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30101', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30103', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30105', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30107', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30109', 'Count': '1140', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '30111', 'Count': '2280', 'Type': 'PacificSource Health Plans'},
#  {'FIPS': '19041', 'Count': '336', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '19059', 'Count': '336', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '19063', 'Count': '336', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '19093', 'Count': '192', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '19119', 'Count': '336', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '19141', 'Count': '336', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '19143', 'Count': '336', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '19149', 'Count': '336', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '19167', 'Count': '336', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '19193', 'Count': '336', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38001', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38003', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38005', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38007', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38009', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38011', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38013', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38015', 'Count': '352', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38017', 'Count': '352', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38019', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38021', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38023', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38025', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38027', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38029', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38031', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38033', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38035', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38037', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38039', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38041', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38043', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38045', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38047', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38049', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38051', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38053', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38055', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38057', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38059', 'Count': '352', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38061', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38063', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38065', 'Count': '352', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38067', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38069', 'Count': '176', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '38071', 'Count': '176', 'Type': 'Sanford Health Plan'},
# ...
#  {'FIPS': '46067', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46069', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46071', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46073', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46075', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46077', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46079', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46081', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46083', 'Count': '544', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46085', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46087', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46089', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46091', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46093', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46095', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46097', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46099', 'Count': '544', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46101', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46103', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46105', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46107', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46109', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46111', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46115', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46117', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46119', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46121', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46123', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46125', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46127', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46129', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46135', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '46137', 'Count': '272', 'Type': 'Sanford Health Plan'},
#  {'FIPS': '55001',
#   'Count': '4536',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55003',
#   'Count': '3240',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55005',
#   'Count': '4104',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55007',
#   'Count': '3240',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55011',
#   'Count': '1224',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55013',
#   'Count': '3240',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55017',
#   'Count': '2736',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55019',
#   'Count': '5508',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55031',
#   'Count': '3240',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55033',
#   'Count': '2736',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55035',
#   'Count': '2736',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55037',
#   'Count': '2268',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55041',
#   'Count': '4536',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55051',
#   'Count': '4536',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55053',
#   'Count': '4752',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55057',
#   'Count': '6156',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55067',
#   'Count': '4536',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55069',
#   'Count': '5508',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55073',
#   'Count': '5508',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55081',
#   'Count': '4104',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55085',
#   'Count': '5508',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55091',
#   'Count': '2880',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55097',
#   'Count': '5508',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55099',
#   'Count': '5508',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55107',
#   'Count': '4320',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55113',
#   'Count': '3240',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55115',
#   'Count': '6588',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55119',
#   'Count': '4536',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55121',
#   'Count': '4752',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55125',
#   'Count': '5508',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55129',
#   'Count': '3240',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55135',
#   'Count': '4536',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55137',
#   'Count': '3024',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '55141',
#   'Count': '5508',
#   'Type': 'Security Health Plan of Wisconsin, Inc.'},
#  {'FIPS': '39005', 'Count': '60', 'Type': 'Summa Insurance Company, Inc.'},
#  {'FIPS': '39007', 'Count': '60', 'Type': 'Summa Insurance Company, Inc.'},
#  {'FIPS': '39019', 'Count': '300', 'Type': 'Summa Insurance Company, Inc.'},
#  {'FIPS': '39035', 'Count': '60', 'Type': 'Summa Insurance Company, Inc.'},
#  {'FIPS': '39043', 'Count': '60', 'Type': 'Summa Insurance Company, Inc.'},
#  {'FIPS': '39055', 'Count': '60', 'Type': 'Summa Insurance Company, Inc.'},
#  {'FIPS': '39075', 'Count': '300', 'Type': 'Summa Insurance Company, Inc.'},
#  {'FIPS': '39077', 'Count': '60', 'Type': 'Summa Insurance Company, Inc.'},
#  {'FIPS': '39085', 'Count': '60', 'Type': 'Summa Insurance Company, Inc.'},
#  {'FIPS': '39093', 'Count': '60', 'Type': 'Summa Insurance Company, Inc.'},
#  {'FIPS': '39099', 'Count': '60', 'Type': 'Summa Insurance Company, Inc.'},
#  {'FIPS': '39103', 'Count': '180', 'Type': 'Summa Insurance Company, Inc.'},
#  {'FIPS': '39123', 'Count': '60', 'Type': 'Summa Insurance Company, Inc.'},
#  {'FIPS': '39133', 'Count': '180', 'Type': 'Summa Insurance Company, Inc.'},
#  {'FIPS': '39143', 'Count': '60', 'Type': 'Summa Insurance Company, Inc.'},
#  {'FIPS': '39151', 'Count': '660', 'Type': 'Summa Insurance Company, Inc.'},
#  {'FIPS': '39153', 'Count': '660', 'Type': 'Summa Insurance Company, Inc.'},
#  {'FIPS': '39155', 'Count': '60', 'Type': 'Summa Insurance Company, Inc.'},
#  {'FIPS': '39157', 'Count': '300', 'Type': 'Summa Insurance Company, Inc.'},
#  {'FIPS': '39169', 'Count': '300', 'Type': 'Summa Insurance Company, Inc.'},
#  {'FIPS': '42003', 'Count': '2664', 'Type': 'UPMC Health Coverage, Inc.'},
#  {'FIPS': '42005', 'Count': '2484', 'Type': 'UPMC Health Coverage, Inc.'},
#  {'FIPS': '42007', 'Count': '2664', 'Type': 'UPMC Health Coverage, Inc.'},
#  {'FIPS': '42009', 'Count': '1908', 'Type': 'UPMC Health Coverage, Inc.'},
#  {'FIPS': '42013', 'Count': '1944', 'Type': 'UPMC Health Coverage, Inc.'},
#  {'FIPS': '42019', 'Count': '2664', 'Type': 'UPMC Health Coverage, Inc.'},
#  {'FIPS': '42021', 'Count': '1908', 'Type': 'UPMC Health Coverage, Inc.'},
#  {'FIPS': '42023', 'Count': '1944', 'Type': 'UPMC Health Coverage, Inc.'},
#  {'FIPS': '42031', 'Count': '2232', 'Type': 'UPMC Health Coverage, Inc.'},
#  {'FIPS': '42033', 'Count': '1944', 'Type': 'UPMC Health Coverage, Inc.'},
#  {'FIPS': '42039', 'Count': '2772', 'Type': 'UPMC Health Coverage, Inc.'},
#  {'FIPS': '42047', 'Count': '2232', 'Type': 'UPMC Health Coverage, Inc.'},
#  {'FIPS': '42049', 'Count': '2952', 'Type': 'UPMC Health Coverage, Inc.'},
#  {'FIPS': '42051', 'Count': '2448', 'Type': 'UPMC Health Coverage, Inc.'},
#  {'FIPS': '42053', 'Count': '2232', 'Type': 'UPMC Health Coverage, Inc.'},
#  {'FIPS': '42059', 'Count': '2448', 'Type': 'UPMC Health Coverage, Inc.'},
#  {'FIPS': '42061', 'Count': '1908', 'Type': 'UPMC Health Coverage, Inc.'},
#  {'FIPS': '42063', 'Count': '2484', 'Type': 'UPMC Health Coverage, Inc.'},
#  {'FIPS': '42065', 'Count': '1980', 'Type': 'UPMC Health Coverage, Inc.'},
#  {'FIPS': '42073', 'Count': '2484', 'Type': 'UPMC Health Coverage, Inc.'},
#  {'FIPS': '42083', 'Count': '2772', 'Type': 'UPMC Health Coverage, Inc.'},
#  {'FIPS': '42085', 'Count': '2736', 'Type': 'UPMC Health Coverage, Inc.'},
#  {'FIPS': '42105', 'Count': '2232', 'Type': 'UPMC Health Coverage, Inc.'},
#  {'FIPS': '42111', 'Count': '1908', 'Type': 'UPMC Health Coverage, Inc.'},
#  {'FIPS': '42121', 'Count': '2196', 'Type': 'UPMC Health Coverage, Inc.'},
#  {'FIPS': '42123', 'Count': '2736', 'Type': 'UPMC Health Coverage, Inc.'},
#  {'FIPS': '42125', 'Count': '2664', 'Type': 'UPMC Health Coverage, Inc.'},
#  {'FIPS': '42129', 'Count': '2664', 'Type': 'UPMC Health Coverage, Inc.'},
#  {'FIPS': '42003', 'Count': '7992', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42005', 'Count': '6072', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42007', 'Count': '7992', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42009', 'Count': '5724', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42011', 'Count': '368', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42013', 'Count': '5832', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42019', 'Count': '7992', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42021', 'Count': '4664', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42023', 'Count': '4752', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42027', 'Count': '5280', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42031', 'Count': '6944', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42033', 'Count': '4752', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42039', 'Count': '8624', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42047', 'Count': '6944', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42049', 'Count': '10824', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42051', 'Count': '7344', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42053', 'Count': '6944', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42059', 'Count': '5984', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42061', 'Count': '4664', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42063', 'Count': '6072', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42065', 'Count': '4840', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42073', 'Count': '7452', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42081', 'Count': '540', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42083', 'Count': '8624', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42085', 'Count': '10032', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42105', 'Count': '6944', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42111', 'Count': '4664', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42117', 'Count': '540', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42121', 'Count': '8052', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42123', 'Count': '8512', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42125', 'Count': '7992', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '42129', 'Count': '7992', 'Type': 'UPMC Health Options, Inc.'},
#  {'FIPS': '22001', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22003', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22005', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22007', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22009', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22011', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22013', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22015', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22017', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22019', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22021', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22023', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22025', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22027', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22029', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22031', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22033', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22035', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22037', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22039', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22041', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22043', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22045', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22047', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22049', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22051', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22053', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22055', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22057', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22059', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22061', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22063', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22065', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22067', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22069', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22071', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22073', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22075', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22077', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22079', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22081', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22083', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22085', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22087', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22089', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22091', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22093', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22095', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22097', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22099', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22101', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22103', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22105', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22107', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22109', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22111', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22113', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22115', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22117', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22119', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22121', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22123', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22125', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'},
#  {'FIPS': '22127', 'Count': '90', 'Type': 'Vantage Health Plan, Inc.'}]

# %%
app = Flask(__name__)

@app.route("/")
def index():
    return render_template("index.html")
    
@app.route("/data")
def data():
    return render_template("data.html")
    
@app.route("/conclusions")
def conclusions():
    return render_template("conclusions.html")
    
@app.route("/info")
def welcome():
    return 'Available routes:/state_count15, /fips_count15, /state_metal15, /fips_metal15, /state_issuer15, /fips_issuer15, /state_type15, /fips_type15, /state_count16, /fips_count16, /state_metal16, /fips_metal16, /state_issuer16, /fips_issuer16, /state_type16, /fips_type16, /state_count17, /fips_count17, /state_metal17, /fips_metal17, /state_issuer17, /fips_issuer17, /state_type17, /fips_type17, /state_count18, /fips_count18, /state_metal18, /fips_metal18, /state_issuer18, /fips_issuer18, /state_type18, /fips_type18'

@app.route("/state_count15")
def stateCount15():
    return jsonify(state15_count_obs)

@app.route("/fips_count15")
def fipsCount15():
    return jsonify(fips15_count_obs)

@app.route("/state_metal15")
def stateMetal15():
    return jsonify(state15_metal_obs)

@app.route("/fips_metal15")
def fipsMetal15():
    return jsonify(fips15_metal_obs)

@app.route("/state_issuer15")
def stateIssuer15():
    return jsonify(state15_issuer_obs)

@app.route("/fips_issuer15")
def fipsIssuer15():
    return jsonify(fips15_issuer_obs)

@app.route("/state_type15")
def stateType15():
    return jsonify(state15_type_obs)

@app.route("/fips_type15")
def fipsType15():
    return jsonify(fips15_type_obs)
##end of year


@app.route("/state_count16")
def stateCount16():
    return jsonify(state16_count_obs)

@app.route("/fips_count16")
def fipsCount16():
    return jsonify(fips16_count_obs)

@app.route("/state_metal16")
def stateMetal16():
    return jsonify(state16_metal_obs)

@app.route("/fips_metal16")
def fipsMetal16():
    return jsonify(fips16_metal_obs)

@app.route("/state_issuer16")
def stateIssuer16():
    return jsonify(state16_issuer_obs)

@app.route("/fips_issuer16")
def fipsIssuer16():
    return jsonify(fips16_issuer_obs)

@app.route("/state_type16")
def stateType16():
    return jsonify(state16_type_obs)

@app.route("/fips_type16")
def fipsType16():
    return jsonify(fips16_type_obs)
##end of year

@app.route("/state_count17")
def stateCount17():
    return jsonify(state17_count_obs)

@app.route("/fips_count17")
def fipsCount17():
    return jsonify(fips17_count_obs)

@app.route("/state_metal17")
def stateMetal17():
    return jsonify(state17_metal_obs)

@app.route("/fips_metal17")
def fipsMetal17():
    return jsonify(fips17_metal_obs)

@app.route("/state_issuer17")
def stateIssuer17():
    return jsonify(state17_issuer_obs)

@app.route("/fips_issuer17")
def fipsIssuer17():
    return jsonify(fips17_issuer_obs)

@app.route("/state_type17")
def stateType17():
    return jsonify(state17_type_obs)

@app.route("/fips_type17")
def fipsType17():
    return jsonify(fips17_type_obs)
##end of year

@app.route("/state_count18")
def stateCount18():
    return jsonify(state18_count_obs)

@app.route("/fips_count18")
def fipsCount18():
    return jsonify(fips18_count_obs)

@app.route("/state_metal18")
def stateMetal18():
    return jsonify(state18_metal_obs)

@app.route("/fips_metal18")
def fipsMetal18():
    return jsonify(fips18_metal_obs)

@app.route("/state_issuer18")
def stateIssuer18():
    return jsonify(state18_issuer_obs)

@app.route("/fips_issuer18")
def fipsIssuer18():
    return jsonify(fips18_issuer_obs)

@app.route("/state_type18")
def stateType18():
    return jsonify(state18_type_obs)

@app.route("/fips_type18")
def fipsType18():
    return jsonify(fips18_type_obs)

##end of year
if __name__ == '__main__':
    app.run(debug=True)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Restarting with stat
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\ Derek\anaconda\Anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3304: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
